# %% [markdown]
# # **A - A_BubbleSort**
#
# Now, given an array of N integers, you have to find out how many swap opeartions occur if the Bubble Sort algorithm is used to sort the array.
#
# **Input**
#
# Input begins with a line containing an integer T (1<=T<=100), denoting the number of test cases. Then T test cases follow. Each test case begins with a line containing an integer N (1<=N<=10000), denoting the number of integers in the array, followed by a line containing N space separated 32-bit integers.
#
# **Output**
#
# For each test case, output a single line in the format Case X: Y, where X denotes the test case number and Y denotes the number of swap operations needed modulo 10000007.
#
# **Example**
#
# Input:
#
# 1
#
# 4
#
# 3 2 1 4
#
# Output:
#
# Case 1: 3

# %%
my_list = [3, 2, 1, 4]

def swap(list, i, j):
    list[i], list[j] = list[j], list[i]

def bouble_sort(list):
    n = len(list)
    swapped = 0
    for j in range(n):
        for i in range((n-j)-1):
            if list[i] > list[i+1]:
                swap(list, i, i+1)
                swapped += 1
    return list, swapped

print(bouble_sort(my_list))
# Out:
# ([1, 2, 3, 4], 3)

# %%
no_of_test_cases = int(input())

for n in range(no_of_test_cases):
    no_of_int = int(input())

    input_list = list(map(int,input().split()))


    def swap(list, i,j):
        list[i], list[j] = list[j], list[i]

    def bouble_sort(list):
        swapped = 0
        n = len(list)
        for i in range(n):
            for j in range(n-i-1):
                if list[j] > list[j+1]:
                    swap(list, j,j+1)
                    swapped += 1
        
        return swapped

    print(f"Case {n+1}: {bouble_sort(input_list)}")
# Out:
# Case 1: 3

# %%
no_of_test_cases = int(input())

for t in range(no_of_test_cases):
    no_of_int = int(input())

    input_list = list(map(int,input().split()))

    swapped = 0
    n = len(input_list)
    for i in range(n):
        for j in range(n-i-1):
            if input_list[j] > input_list[j+1]:
                input_list[j], input_list[j+1] = input_list[j+1], input_list[j]
                swapped += 1
 
    print(f"Case {t+1}: {swapped}")
# Out:
# Case 1: 3

# %%
import signal
import time

class TimeoutException(Exception):
    pass

def timeout_handler(signum, frame):
    raise TimeoutException

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

def sort_with_timeout(arr, timeout=0.5):
    signal.signal(signal.SIGALRM, timeout_handler)
    signal.setitimer(signal.ITIMER_REAL, timeout)
    
    try:
        bubble_sort(arr)
        signal.alarm(0)  # Disable the alarm
        return arr
    except TimeoutException:
        print("Sorting timed out!")
        return None

# Example usage
if __name__ == "__main__":
    arr = [64, 34, 25, 12, 22, 11, 90]
    sorted_arr = sort_with_timeout(arr)
    if sorted_arr:
        print("Sorted array:", sorted_arr)
    else:
        print("Sorting was not completed within the time limit.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 32
#      30 if __name__ == "__main__":
#      31     arr = [64, 34, 25, 12, 22, 11, 90]
# ---> 32     sorted_arr = sort_with_timeout(arr)
#      33     if sorted_arr:
#      34         print("Sorted array:", sorted_arr)
#
# Cell In[1], line 18, in sort_with_timeout(arr, timeout)
#      17 def sort_with_timeout(arr, timeout=0.5):
# ---> 18     signal.signal(signal.SIGALRM, timeout_handler)
#      19     signal.setitimer(signal.ITIMER_REAL, timeout)
#      21     try:
#
# AttributeError: module 'signal' has no attribute 'SIGALRM'

# %%
import time

def bubble_sort_with_time_limit(arr, time_limit_ms):
    start_time = time.time()  # Record the start time
    n = len(arr)
    
    for i in range(n - 1):
        swapped = 0
        for j in range(n - i - 1):
            # Check if the time limit has been exceeded
            elapsed_time_ms = (time.time() - start_time) * 1000
            if elapsed_time_ms > time_limit_ms:
                print(f"Time limit exceeded! Returning partially sorted list.")
                return arr
            
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]  # Swap
                swapped += 1
        
        # If no two elements were swapped, the array is already sorted
        if swapped != 0:
            break

    return swapped, arr


# Example usage
# array = [64, 34, 25, 12, 22, 11, 90]
# sorted_array = bubble_sort_with_time_limit(array, 500)  # 500 ms time limit
# print("Sorted array:", sorted_array)

n = int(input())
for _ in range(n):
    m = int(input())
    array = list(map(int, input().split()))
    sorted_array = bubble_sort_with_time_limit(array, 500)  # 500 ms time limit
    print(f"Case {_ + 1}:", sorted_array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 32
#      24     return swapped, arr
#      27 # Example usage
#      28 # array = [64, 34, 25, 12, 22, 11, 90]
#      29 # sorted_array = bubble_sort_with_time_limit(array, 500)  # 500 ms time limit
#      30 # print("Sorted array:", sorted_array)
# ---> 32 n = int(input())
#      33 for _ in range(n):
#      34     m = int(input())
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def merge_and_count(arr, temp_arr, left, mid, right):
    """
    Merge two halves and count inversions.
    """
    i = left    # Index for left subarray
    j = mid + 1 # Index for right subarray
    k = left    # Index for merged subarray
    inv_count = 0
    mod = 10000007
    
    # Merge the two halves while counting inversions
    while i <= mid and j <= right:
        if arr[i] <= arr[j]:
            temp_arr[k] = arr[i]
            i += 1
        else:
            # All remaining elements in left subarray form inversions
            temp_arr[k] = arr[j]
            inv_count = (inv_count + (mid - i + 1)) % mod
            j += 1
        k += 1
    
    # Copy remaining elements from left subarray
    while i <= mid:
        temp_arr[k] = arr[i]
        i += 1
        k += 1
    
    # Copy remaining elements from right subarray
    while j <= right:
        temp_arr[k] = arr[j]
        j += 1
        k += 1
    
    # Copy the merged elements back into the original array
    for i in range(left, right + 1):
        arr[i] = temp_arr[i]
    
    return inv_count

def merge_sort_and_count(arr, temp_arr, left, right):
    """
    Use Merge Sort to sort the array and count inversions.
    """
    inv_count = 0
    if left < right:
        mid = (left + right) // 2
        
        # Count inversions in the left half
        inv_count += merge_sort_and_count(arr, temp_arr, left, mid)
        inv_count %= 10000007
        
        # Count inversions in the right half
        inv_count += merge_sort_and_count(arr, temp_arr, mid + 1, right)
        inv_count %= 10000007
        
        # Count inversions during merge
        inv_count += merge_and_count(arr, temp_arr, left, mid, right)
        inv_count %= 10000007
    
    return inv_count

def main():
    import sys
    input = sys.stdin.read
    data = input().splitlines()
    
    T = int(data[0])  # Number of test cases
    results = []
    idx = 1
    
    for t in range(1, T + 1):
        N = int(data[idx])  # Size of the array
        idx += 1
        arr = list(map(int, data[idx].split()))
        idx += 1
        
        # Count inversions using Merge Sort
        temp_arr = [0] * N
        swap_count = merge_sort_and_count(arr, temp_arr, 0, N - 1)
        
        # Append result in the required format
        results.append(f"Case {t}: {swap_count}")
    
    # Print all results
    print("\n".join(results))

if __name__ == "__main__":
    main()

# %%
def merge_and_count(arr, temp_arr, left, mid, right):
    i = left  
    j = mid + 1
    k = left    
    inv_count = 0
    mod = 10000007
    
 
    while i <= mid and j <= right:
        if arr[i] <= arr[j]:
            temp_arr[k] = arr[i]
            i += 1
        else:
            temp_arr[k] = arr[j]
            inv_count = (inv_count + (mid - i + 1)) % mod
            j += 1
        k += 1

    while i <= mid:
        temp_arr[k] = arr[i]
        i += 1
        k += 1
    
    while j <= right:
        temp_arr[k] = arr[j]
        j += 1
        k += 1
    
    for i in range(left, right + 1):
        arr[i] = temp_arr[i]
    
    return inv_count

def merge_sort_and_count(arr, temp_arr, left, right):

    inv_count = 0
    if left < right:
        mid = (left + right) // 2
        
        inv_count += merge_sort_and_count(arr, temp_arr, left, mid)
        inv_count %= 10000007
        
        inv_count += merge_sort_and_count(arr, temp_arr, mid + 1, right)
        inv_count %= 10000007
        
        inv_count += merge_and_count(arr, temp_arr, left, mid, right)
        inv_count %= 10000007
    
    return inv_count

def main():
    import sys
    input = sys.stdin.read
    data = input().splitlines()
    
    T = int(data[0])  
    results = []
    idx = 1
    
    for t in range(1, T + 1):
        N = int(data[idx]) 
        idx += 1
        arr = list(map(int, data[idx].split()))
        idx += 1
        
        temp_arr = [0] * N
        swap_count = merge_sort_and_count(arr, temp_arr, 0, N - 1)
        
        results.append(f"Case {t}: {swap_count}")
    
    print("\n".join(results))

if __name__ == "__main__":
    main()

# %% [markdown]
# # **B - B_InsertionSort**
#
#
# Implement Insertion Sort and print the index at which the ith element gets inserted [i>=1].
#
#
# **Input Format**
#
# First line of input contains T - number of test cases. Its followed by 2T lines. First line of each test case contains N - size of the array. The next line contains N integers - elements of the array.
#
#
# **Constraints**
#
# 1 <= T <= 100
#
# 2 <= N <= 100
#
# -1000 <= ar[i] <= 1000
#
#
# **Output Format**
#
# For each test case, print the index at which the ith element gets inserted [i>=1], separated by space. Separate the output of different tests by newline.
#
#
#
# **Input:**
#
# 4
#
# 8
#
# 176 -272 -272 -45 269 -327 -945 176
#
# 2
#
# -274 161
#
# 7
#
# 274 204 -161 481 -606 -767 -351
#
# 2
#
# 154 -109
#
#
# **Output:**
#
# 0 1 2 4 0 0 6
#
# 1
#
# 0 0 3 0 0 2
#
# 0

# %%
my_list = [176, -272, -272, -45, 269, -327, -945, 176]

def insetion_sort(list):
    for i in range(1, len(list)):
        key = list[i]
        j = i-1

        while j>=0 and list[j]>key:
            list[j+1] = list[j]
            j = j-1
            # print(list)

        list[j+1] = key
        print(j+1, end= " ")

        # print(list)

insetion_sort(my_list)
# Out:
# 0 1 2 4 0 0 6

# %%
no_of_test_cases = int(input())

for _ in range(no_of_test_cases):
    n = int(input())

    lst = list(map(int, input().split()))

    for i in range(1, n):
        key = lst[i]
        j = i-1

        while (j>=0) and (lst[j]>key):
            lst[j+1] = lst[j]
            j -= 1
        
        lst[j+1] = key
        print(j+1, end=" ")
    
    print()
    # print(lst)
# Out:
# 0 1 2 4 0 0 6
# 1
# 0 0 3 0 0 2
# 0

# %% [markdown]
# # **C - C_Laptop**
#
# One day Dima and Alex had an argument about the price and quality of laptops. Dima thinks that the more expensive a laptop is, the better it is. Alex disagrees. Alex thinks that there are two laptops, such that the price of the first laptop is less (strictly smaller) than the price of the second laptop but the quality of the first laptop is higher (strictly greater) than the quality of the second laptop.
#
# Please, check the guess of Alex. You are given descriptions of n laptops. Determine whether two described above laptops exist.
#
# **Input**
#
# The first line contains an integer n (1 ≤ n ≤ 105) — the number of laptops.
#
# Next n lines contain two integers each, ai and bi (1 ≤ ai, bi ≤ n), where ai is the price of the i-th laptop, and bi is the number that represents the quality of the i-th laptop (the larger the number is, the higher is the quality).
#
# All ai are distinct. All bi are distinct.
#
# **Output**
#
# If Alex is correct, print "Happy Alex", otherwise print "Poor Alex" (without the quotes).
#
# **Examples**
#
# Input:
#
# 2
#
# 1 2
#
# 2 1
#
#
# Output:
#
# Happy Alex

# %%
n = int(input())
laptops = []

for i in range(n):
    price, quality = map(int, input().split())
    laptops.append((price, quality))

laptops.sort()
alex_happy = False

for j in range(1,n):
    if laptops[j-1][1] > laptops[j][1]:
        alex_happy = True
        break

if alex_happy:
    print("Happy Alex")
else:
    print("Poor Alex")

# %% [markdown]
# # **D - D_SortTheArray**

# %%
def bouble_sort(list):
    n = len(list)
    for i in range(n):
        for j in range(n-i-1):
            if list[j] > list[j+1]:
                list[j], list[j+1] = list[j+1], list[j]
    # print(list)
    return list


n = int(input())
lst = list(map(int, input().split()))

start, end = -1, -1


for i in range(n-1):
    if lst[i] > lst[i+1]:
        start = i
        break

if start == -1:
    print("yes")
    print(1,1)
else:
    for j in range(n-1,0,-1):
        if lst[j-1] > lst[j]:
            end = j
            break
    

    reversed_list = lst[:start] + lst[start:end+1][::-1] + lst[end+1:]
    # print("my", reversed_list)

    if reversed_list == bouble_sort(lst):
        print("yes")
        print(f"{start+1}  {end+1}")
    else:
        print("no")
# Out:
# yes
# 1 1

# %%
def counting_sort(list):
    count = [0] * (max(list) + 1)

    for i in list:
        count[i] += 1

    for j in range(1, len(count)):
        count[j] += count[j-1]

    output_list = [0] * len(list)

    for x in list:
        index = count[x] - 1
        output_list[index] = x
        count[x] -= 1

    return output_list


n = int(input())
lst = list(map(int, input().split()))

start, end = -1, -1


for i in range(n-1):
    if lst[i] > lst[i+1]:
        start = i
        break

if start == -1:
    print("yes")
    print(1,1)
else:
    for j in range(n-1,0,-1):
        if lst[j-1] > lst[j]:
            end = j
            break
    

    reversed_list = lst[:start] + lst[start:end+1][::-1] + lst[end+1:]
    # print("my", reversed_list)

    if reversed_list == counting_sort(lst):
        print("yes")
        print(f"{start+1}  {end+1}")
    else:
        print("no")
# Out:
# yes
# 1  3

# %%
n = int(input())
lst = list(map(int, input().split()))

start, end = -1, -1


for i in range(n-1):
    if lst[i] > lst[i+1]:
        start = i
        break

if start == -1:
    print("yes")
    print(1,1)
else:
    for j in range(n-1,0,-1):
        if lst[j-1] > lst[j]:
            end = j
            break
    

    reversed_list = lst[:start] + lst[start:end+1][::-1] + lst[end+1:]
    # print("my", reversed_list)

    if reversed_list == sorted(lst):
        print("yes")
        print(f"{start+1}  {end+1}")
    else:
        print("no")
# Out:
# yes
# 1  3

# %% [markdown]
# # **E - E_HelpfulMath**
#
# Xenia the beginner mathematician is a third year student at elementary school. She is now learning the addition operation.
#
# The teacher has written down the sum of multiple numbers. Pupils should calculate the sum. To make the calculation easier, the sum only contains numbers 1, 2 and 3. Still, that isn't enough for Xenia. She is only beginning to count, so she can calculate a sum only if the summands follow in non-decreasing order. For example, she can't calculate sum 1+3+2+1 but she can calculate sums 1+1+2 and 3+3.
#
# You've got the sum that was written on the board. Rearrange the summans and print the sum in such a way that Xenia can calculate the sum.
#
# **Input**
#
# The first line contains a non-empty string s — the sum Xenia needs to count. String s contains no spaces. It only contains digits and characters "+". Besides, string s is a correct sum of numbers 1, 2 and 3. String s is at most 100 characters long.
#
# **Output**
#
# Print the new sum that Xenia can count.
#
# **Examples**
#
# Input:
#
# 3+2+1
#
# Output:
#
# 1+2+3
#
# Input:
#
# 1+1+3+1+3
#
# Output:
#
# 1+1+1+3+3
#
# Input:
#
# 2
#
# Output:
#
# 2

# %%
math_input = list(map(int, input().split("+")))

def counting_sort(list):
    count = [0] * (max(list) + 1)

    for i in list:
        count[i] += 1

    for j in range(1, len(count)):
        count[j] += count[j-1]

    output_list = [0] * len(list)

    for x in list:
        index = count[x] - 1
        output_list[index] = x
        count[x] -= 1

    return output_list

result = counting_sort(math_input)
print("+".join(map(str,result)))
# Out:
# 1+1+1+3+3

# %% [markdown]
# # **F - F_Apartments**
#
# There are n applicants and m free apartments. Your task is to distribute the apartments so that as many applicants as possible will get an apartment.
#
# Each applicant has a desired apartment size, and they will accept any apartment whose size is close enough to the desired size.
#
# **Input**
#
# The first input line has three integers n, m, and k: the number of applicants, the number of apartments, and the maximum allowed difference.
#
# The next line contains n integers a1 ,a2 ,…,an : the desired apartment size of each applicant. If the desired size of an applicant is x, he or she will accept any apartment whose size is between x−k and x+k.
#
# The last line contains m integers b1,b2,…,bm : the size of each apartment.
#
# **Output**
#
# Print one integer: the number of applicants who will get an apartment.
#
# **Constraints**
#
# 1) 1≤n,m≤2⋅10^5
#
# 2) 0≤k≤10^9
#
# 3) 1≤ai ,bi ≤10^9
#
# **Example**
#
# Input:
#
# 4 3 5
#
# 60 45 80 60
#
# 30 60 75
#
# Output:
#
# 2

# %%
n = list(map(int, input().split()))
m = list(map(int, input().split()))
k = list(map(int, input().split()))

sold = 0
for i in m:
    for j in k:
        if j in range(i-n[2], i+n[2]+1):
            sold += 1
            k.remove(j)

print(sold)
# Out:
# 2

# %%
def bouble_sort(list):
    n = len(list)
    for i in range(n):
        for j in range(1, n-i-1):
            if list[j] > list[j+1]:
                list[j], list[j+1] = list[j+1], list[j]

    return list

n,m,k = map(int, input().split())
apartmentts = bouble_sort(list(map(int, input().split())))
aplicants = bouble_sort(list(map(int, input().split())))

matched = 0
i = 0
j = 0

while (i<n) and (j<m):
    if abs(apartmentts[i] - aplicants[j]) <= k:
        matched += 1
        i += 1
        j += 1
    elif apartmentts[i] > aplicants[j]:
        j += 1
    else:
        i += 1

print(matched)
# Out:
# 2

# %%
def counting_sort(list):
    if not lst:  # Check for empty lists
        return lst
    count = [0] * (max(list) + 1)

    for i in list:
        count[i] += 1

    for j in range(1, len(count)):
        count[j] += count[j-1]

    output_list = [0] * len(list)

    for x in list:
        index = count[x] - 1
        output_list[index] = x
        count[x] -= 1

    return output_list

n,m,k = map(int, input().split())
apartmentts = counting_sort(list(map(int, input().split())))
aplicants = counting_sort(list(map(int, input().split())))

matched = 0
i = 0
j = 0

while (i<n) and (j<m):
    if abs(apartmentts[i] - aplicants[j]) <= k:
        matched += 1
        i += 1
        j += 1
    elif apartmentts[i] > aplicants[j]:
        j += 1
    else:
        i += 1

print(matched)

print(apartmentts)
print(aplicants)
# Out:
# 3
# [45, 60, 60, 80]
# [55, 60, 75]

# %%
# Jamme
n, m, k = map(int, input().split())
applicants = list(map(int, input().split()))
apartments = list(map(int, input().split()))

applicants.sort()
apartments.sort()
i = 0
j = 0
matches = 0
while i < n and j < m:
    if apartments[j] < applicants[i] - k:
        j += 1
    elif apartments[j] > applicants[i] + k:
        i += 1
    else:
        matches += 1
        i += 1
        j += 1

print(matches)
# Out:
# 2

# %% [markdown]
# # **G - G_DistinctNumbers**

# %%
# import pandas as pd

n = int(input())
lst = list(map(int, input().split()))

distinct_values = []

for i in lst:
    if i not in distinct_values:
        distinct_values.append(i)
        
print(len(distinct_values))

# print(len(pd.unique(lst)))
# Out:
# 2

# %%
n = int(input())
lst = list(map(int, input().split()))

distinct_values = []
distinct_count = 0

for i in lst:
    if i not in distinct_values:
        distinct_values.append(i)
        distinct_count += 1

print(distinct_count)
# Out:
# 2

# %%
n = int(input())
print(len(set(list(map(int, input().split())))))
# Out:
# 2

# %%
n = int(input())
lst = list(map(int, input().split()))

unique_elements = set()

for num in lst:
    unique_elements.add(num)

print(len(unique_elements))
# Out:
# 2

# %%
def distinct_values_map(arr):
    freq_map = {}  # Create an empty dictionary to store frequency of each element
    for num in arr:
        freq_map[num] = freq_map.get(num, 0) + 1  # Increment frequency count for each element
    return len(freq_map)  # Return the number of distinct values

# Main function
def main():
    n = int(input())
    arr = list(map(int, input().split())) 
    # Call the distinct_values_map function to get the number of distinct values
    distinct_count = distinct_values_map(arr)
    # Print the number of distinct values
    print("Number of distinct values are:", distinct_count)

# Execute main function
if __name__ == "__main__":
    main()

# %%
import sys

def count_distinct_values():
    # Efficient input reading
    input = sys.stdin.read
    data = input().split()

    # Use a set to directly count unique values
    distinct_values = set(data[1:])  # Skip the first number (size of the list)

    # Output the number of unique values
    print(len(distinct_values))

# Call the function
count_distinct_values()

# %% [markdown]
# # **H - H_FerrisWheel**

# %%
n, x = map(int, input().split())
lst = list(map(int, input().split()))

flag = True

for i in lst:
    if i > x:
        flag = False

if flag:
    print((sum(lst) // x) + 1)
# Out:
# 3

# %%
def solve(arr, N, X):
    # Sort the array in ascending order
    arr.sort()

    # Maintain two pointers for children with heaviest and lightest weight
    l, h = 0, N - 1

    # Variable to store the number of gondolas
    ans = 0

    while h >= l:
        # If the heaviest and lightest child can fit in a gondola, then pair them up
        if arr[l] + arr[h] <= X:
            ans += 1
            l += 1
            h -= 1
        # If the heaviest and lightest child cannot fit in a gondola,
        # then put the heaviest child in a separate gondola
        else:
            ans += 1
            h -= 1

    return ans

# Sample Input
n, x = map(int, input().split())
lst = list(map(int, input().split()))

print(solve(lst, n, x))

# %% [markdown]
# # **Reverse of single linked list**

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class SingleLinkedList:
    def __init__(self):
        self.head = None
    
    def insertAtBegin(self, data):
        new_item = Node(data)
        if self.head is None:
            self.head = new_item
            return
        else:
            new_item.next = self.head
            self.head = new_item

    def insertAtEnd(self, data):
        new_item = Node(data)
        if self.head is None:
            self.head = new_item
            return
        else:
            current = self.head
            while (current.next != None):
                current = current.next
            current.next = new_item

    def display(self):
        current = self.head
        while(current):
            print(current.data, end=" -> ")
            current = current.next
        print(f"None")

    def reverse(self):
        reversed_list = SingleLinkedList()

        current = self.head
        while(current):
            reversed_list.insertAtBegin(current.data)
            current = current.next
        
        reversed_list.display()

# %%
list_3 = SingleLinkedList()
list_3.insertAtBegin(4)
list_3.insertAtEnd(63)
list_3.insertAtEnd(47)
list_3.insertAtEnd(31)
list_3.insertAtEnd(78)
list_3.insertAtEnd(12)
list_3.insertAtEnd(9)
list_3.display()
list_3.reverse()
# Out:
# 4 -> 63 -> 47 -> 31 -> 78 -> 12 -> 9 -> None
# 9 -> 12 -> 78 -> 31 -> 47 -> 63 -> 4 -> None
